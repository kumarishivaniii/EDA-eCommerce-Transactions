# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity

customer_features = merged.groupby('CustomerID').agg({
    'TotalValue': 'sum',
    'Quantity': 'sum',
    'ProductID': 'nunique'  # Count unique products purchased
}).reset_index()

# Rename 'ProductID' aggregation for clarity
customer_features.rename(columns={'ProductID': 'ProductDiversity'}, inplace=True)

print(customer_features.head())

from sklearn.metrics.pairwise import cosine_similarity

# Calculate similarity matrix
features = customer_data[numeric_features + ['AccountAge']]
similarity_matrix = cosine_similarity(features)

# Top 3 lookalikes for first 20 customers
lookalikes = {}
for i, customer_id in enumerate(customer_data['CustomerID'][:20]):
    similar_indices = similarity_matrix[i].argsort()[::-1][1:4]
    similar_scores = similarity_matrix[i][similar_indices]
    lookalikes[customer_id] = [(customer_data.iloc[j]['CustomerID'], similar_scores[k])
                               for k, j in enumerate(similar_indices)]

print(lookalikes)

import csv
with open("Lookalike.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerow(["CustomerID", "Lookalikes"])
    for cust_id, matches in lookalikes.items():
        writer.writerow([cust_id, matches])
