# %%
from sklearn.cluster import KMeans
from sklearn.metrics import davies_bouldin_score

# Define the number of clusters
kmeans = KMeans(n_clusters=4, random_state=42)
customer_data['Cluster'] = kmeans.fit_predict(customer_data[numeric_features + ['AccountAge']])

# Calculate clustering performance metrics
db_index = davies_bouldin_score(customer_data[numeric_features + ['AccountAge']], customer_data['Cluster'])
print("Davies-Bouldin Index:", db_index)

# Visualize clusters (e.g., PCA or t-SNE for dimensionality reduction)
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(data=customer_data, x='TotalValue', y='Quantity', hue='Cluster', palette='Set2')
plt.show()
# Visualize clusters using two main dimensions (e.g., TotalValue, Quantity)
sns.scatterplot(
    x=customer_data['TotalValue'],
    y=customer_data['Quantity'],
    hue=customer_data['Cluster'],
    palette="viridis"
)
plt.title("Customer Clusters")
plt.show()

from sklearn.cluster import KMeans
from sklearn.metrics import davies_bouldin_score
import matplotlib.pyplot as plt

# Apply KMeans clustering
kmeans = KMeans(n_clusters=5, random_state=42)
customer_data['Cluster'] = kmeans.fit_predict(customer_data[numeric_features])

# Evaluate clustering
db_index = davies_bouldin_score(customer_data[numeric_features], customer_data['Cluster'])
print("DB Index:", db_index)
